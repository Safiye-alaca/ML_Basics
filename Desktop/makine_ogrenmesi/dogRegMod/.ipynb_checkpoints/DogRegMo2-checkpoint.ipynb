# %%
import pandas as pd
df = pd.read_csv("C:/Users/safye/Desktop/makine_ogrenmesi/dogRegMod/Advertising.csv")
df = df.iloc[:,1:len(df)]
df.head()
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   radio      200 non-null    float64
#  2   newspaper  200 non-null    float64
#  3   sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
import seaborn as sns
sns.jointplot(x = "TV", y = "sales", data = df, kind = "reg");

# %%
from sklearn.linear_model import LinearRegression

# %%
X = df[["TV"]]

# %%
X.head()
# Out:
#       TV
# 0  230.1
# 1   44.5
# 2   17.2
# 3  151.5
# 4  180.8

# %%
y = df[["sales"]]

# %%
reg = LinearRegression()

# %%
model = reg.fit(X, y)

# %%
model
# Out:
# LinearRegression()

# %%
str(model)
# Out:
# 'LinearRegression()'

# %%
dir(model)
# Out:
# ['__abstractmethods__',
#  '__annotations__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__sklearn_clone__',
#  '__sklearn_tags__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abc_impl',
#  '_build_request_for_signature',
#  '_decision_function',
#  '_doc_link_module',
#  '_doc_link_template',
#  '_doc_link_url_param_generator',
#  '_estimator_type',
#  '_get_default_requests',
#  '_get_doc_link',
#  '_get_metadata_request',
#  '_get_param_names',
#  '_get_params_html',
#  '_html_repr',
#  '_parameter_constraints',
#  '_repr_html_',
#  '_repr_html_inner',
#  '_repr_mimebundle_',
#  '_set_intercept',
#  '_validate_params',
#  'coef_',
#  'copy_X',
#  'feature_names_in_',
#  'fit',
#  'fit_intercept',
#  'get_metadata_routing',
#  'get_params',
#  'intercept_',
#  'n_features_in_',
#  'n_jobs',
#  'positive',
#  'predict',
#  'rank_',
#  'score',
#  'set_fit_request',
#  'set_params',
#  'set_score_request',
#  'singular_',
#  'tol']

# %%
model.intercept_
# Out:
# array([7.03259355])

# %%
model.coef_
# Out:
# array([[0.04753664]])

# %% [raw]
# #rkare
# model.score(X,y)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
g = sns.regplot(df["TV"], df["sales"], data=df, ci=None, scatter_kws={'color':'r', 's':9})
g.set_title("Model Denklemi: Sales = 7.03 + TV*0.05")
g.set_ylabel("Satış Sayısı")
g.set_xlabel("TV Harcamaları")
plt.xlim(-10, 310)
plt.ylim(bottom=0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 3
#       1 import seaborn as sns
#       2 import matplotlib.pyplot as plt
# ----> 3 g = sns.regplot(df["TV"], df["sales"], ci=None, scatter_kws={'color':'r', 's':9})
#       4 g.set_title("Model Denklemi: Sales = 7.03 + TV*0.05")
#       5 g.set_ylabel("Satış Sayısı")
#
# TypeError: regplot() takes from 0 to 1 positional arguments but 2 positional arguments (and 2 keyword-only arguments) were given
